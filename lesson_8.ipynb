# %%
import pandas as pd

# %%
df = pd.read_csv('weather.csv', index_col=0)
df
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Sep          77     57.0        103.0          40               0.17
# Jul          77     58.0        105.0          44               0.00
# Aug          77     59.0        102.0          43               0.03
# Jun          75     56.0        107.0          41               0.11
# Oct          73     54.0         96.0          34               0.81
# May          71     53.0         98.0          35               0.48
# Apr          67     50.0         92.0          28               1.02
# Mar          65     48.0         84.0          25               2.34
# Nov          64     48.0         84.0          30               1.70
# Feb          61     45.0         78.0          26               3.02
# Jan          58     42.0         74.0          22               2.05
# Dec          58     42.0         73.0          21               2.56
#
#        naujas_stulpelis  naujas_stulpelis2
# month
# ...

# %%
df = pd.read_csv('LT.csv')

# %%
df.describe()
df
# Out:
#            date   home_team  away_team  home_score  away_score  \
# 0    1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1    1979-07-22     Georgia  Lithuania           5           0
# 2    1979-07-24  Azerbaijan  Lithuania           0           1
# 3    1979-07-28   Lithuania    Ukraine           0           2
# 4    1979-07-30      Russia  Lithuania           2           0
# ..          ...         ...        ...         ...         ...
# 362  2019-09-10   Lithuania   Portugal           1           5
# 363  2019-10-11     Ukraine  Lithuania           2           0
# 364  2019-10-11     Ukraine  Lithuania           2           0
# 365  2019-10-14   Lithuania     Serbia           1           2
# 366  2019-10-14   Lithuania     Serbia           1           2
#
#                   tourniment     city       country
# 0                   Friendly   Moscow  Soviet Union
# 1                   Friendly   Moscow  Soviet Union
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        367 non-null    object
#  1   home_team   367 non-null    object
#  2   away_team   367 non-null    object
#  3   home_score  367 non-null    int64
#  4   away_score  367 non-null    int64
#  5   tourniment  367 non-null    object
#  6   city        367 non-null    object
#  7   country     367 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 23.1+ KB

# %%
df['date'] = pd.to_datetime(df['date'])
df['home_team'] = pd.Categorical(df['home_team'])
df['away_team'] = pd.Categorical(df['away_team'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        367 non-null    datetime64[ns]
#  1   home_team   367 non-null    category
#  2   away_team   367 non-null    category
#  3   home_score  367 non-null    int64
#  4   away_score  367 non-null    int64
#  5   tourniment  367 non-null    object
#  6   city        367 non-null    object
#  7   country     367 non-null    object
# dtypes: category(2), datetime64[ns](1), int64(2), object(3)
# memory usage: 23.0+ KB

# %%
df.tail(10)
# Out:
#           date  home_team  away_team  home_score  away_score  \
# 357 2019-06-10     Serbia  Lithuania           4           1
# 358 2019-06-10     Serbia  Lithuania           4           1
# 359 2019-09-07  Lithuania    Ukraine           0           3
# 360 2019-09-07  Lithuania    Ukraine           0           3
# 361 2019-09-10  Lithuania   Portugal           1           5
# 362 2019-09-10  Lithuania   Portugal           1           5
# 363 2019-10-11    Ukraine  Lithuania           2           0
# 364 2019-10-11    Ukraine  Lithuania           2           0
# 365 2019-10-14  Lithuania     Serbia           1           2
# 366 2019-10-14  Lithuania     Serbia           1           2
#
#                   tourniment      city    country
# 357  UEFA Euro qualification  Belgrade     Serbia
# 358  UEFA Euro qualification  Belgrade     Serbia
# 359  UEFA Euro qualification   Vilnius  Lithuania
# 360  UEFA Euro qualification   Vilnius  Lithuania
# ...

# %%
#kiek kartu zaidem isvykoje
df[ df['away_team'] == 'Lithuania']
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 4   1979-07-30      Russia  Lithuania           2           0
# 5   1979-08-01     Belarus  Lithuania           0           2
# ..         ...         ...        ...         ...         ...
# 354 2019-03-25  Azerbaijan  Lithuania           0           0
# 357 2019-06-10      Serbia  Lithuania           4           1
# 358 2019-06-10      Serbia  Lithuania           4           1
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
#
#                   tourniment      city       country
# 0                   Friendly    Moscow  Soviet Union
# 1                   Friendly    Moscow  Soviet Union
# 2                   Friendly    Moscow  Soviet Union
# ...

# %%
df['away_team'] == 'Lithuania' # mask
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 362    False
# 363     True
# 364     True
# 365    False
# 366    False
# Name: away_team, Length: 367, dtype: bool

# %%
df[ (df['away_team'] == 'Lithuania') & (df['city'] == 'Kharkiv') ]
# Out:
#           date home_team  away_team  home_score  away_score  \
# 196 2010-05-25   Ukraine  Lithuania           4           0
# 363 2019-10-11   Ukraine  Lithuania           2           0
# 364 2019-10-11   Ukraine  Lithuania           2           0
#
#                   tourniment     city  country
# 196                 Friendly  Kharkiv  Ukraine
# 363  UEFA Euro qualification  Kharkiv  Ukraine
# 364  UEFA Euro qualification  Kharkiv  Ukraine

# %%
# Bitwise operator
# and = &
# or = |
# not = ~
#in - .isin( <sarasas> )

# %%
df[ df['away_team'] == 'Lithuania' & df['city'] == 'Kharkiv' ]# error, jei neuzdesim skl
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Donciukas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\array_ops.py:305, in na_logical_op(x, y, op)
#     296 try:
#     297     # For exposition, write:
#     298     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     303     # Then Cases where this goes through without raising include:
#     304     #  (xint or xbool) and (yint or bool)
# --> 305     result = op(x, y)
#     306 except TypeError:
#
# File c:\Users\Donciukas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\roperator.py:54, in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#
# TypeError: unsupported operand type(s) for &: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df[ df['city'].isin( ['Vilnius', 'Kaunas' ] ) ]
# Out:
#           date  home_team away_team  home_score  away_score  \
# 17  1992-09-02  Lithuania   Georgia           1           0
# 18  1992-09-23  Lithuania   Denmark           0           0
# 19  1992-10-14  Lithuania  Slovakia           0           1
# 20  1992-10-28  Lithuania    Latvia           1           1
# 26  1993-04-14  Lithuania   Albania           3           1
# ..         ...        ...       ...         ...         ...
# 360 2019-09-07  Lithuania   Ukraine           0           3
# 361 2019-09-10  Lithuania  Portugal           1           5
# 362 2019-09-10  Lithuania  Portugal           1           5
# 365 2019-10-14  Lithuania    Serbia           1           2
# 366 2019-10-14  Lithuania    Serbia           1           2
#
#                        tourniment     city    country
# 17                       Friendly   Kaunas  Lithuania
# 18   FIFA World Cup qualification  Vilnius  Lithuania
# 19                       Friendly  Vilnius  Lithuania
# ...

# %%
df.loc[ df['city'].isin( ['Vilnius', 'Kaunas' ] ), ['date', 'home_score', 'away_score'] ]
# Out:
#           date  home_score  away_score
# 17  1992-09-02           1           0
# 18  1992-09-23           0           0
# 19  1992-10-14           0           1
# 20  1992-10-28           1           1
# 26  1993-04-14           3           1
# ..         ...         ...         ...
# 360 2019-09-07           0           3
# 361 2019-09-10           1           5
# 362 2019-09-10           1           5
# 365 2019-10-14           1           2
# 366 2019-10-14           1           2
#
# [121 rows x 3 columns]

# %%
# Sukurti naują stulpelį, kuriame būtų paskaičiuota įvarčiu suma
df['ivarciu_suma'] = df['home_score'] +df['away_score']
df
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 3   1979-07-28   Lithuania    Ukraine           0           2
# 4   1979-07-30      Russia  Lithuania           2           0
# ..         ...         ...        ...         ...         ...
# 362 2019-09-10   Lithuania   Portugal           1           5
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
# 365 2019-10-14   Lithuania     Serbia           1           2
# 366 2019-10-14   Lithuania     Serbia           1           2
#
#                   tourniment     city       country  ivarciu_suma
# 0                   Friendly   Moscow  Soviet Union             0
# 1                   Friendly   Moscow  Soviet Union             5
# ...

# %%
# Sukurti naują stulpelį, kuriame būtų paskaičiuotas įvarčių skirtumas
df['ivarciu_skirtumas'] = df['home_score'] - df['away_score']
df
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 3   1979-07-28   Lithuania    Ukraine           0           2
# 4   1979-07-30      Russia  Lithuania           2           0
# ..         ...         ...        ...         ...         ...
# 362 2019-09-10   Lithuania   Portugal           1           5
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
# 365 2019-10-14   Lithuania     Serbia           1           2
# 366 2019-10-14   Lithuania     Serbia           1           2
#
#                   tourniment     city       country  ivarciu_suma  \
# 0                   Friendly   Moscow  Soviet Union             0
# 1                   Friendly   Moscow  Soviet Union             5
# ...

# %%
# Kiek rungtynių baigėsi lygiosiomis?
#lygiosios = df['ivarciu_skirtumas'] == 0
#df_1 = df[lygiosios]
#df_1
df[ df['ivarciu_skirtumas'] == 0 ]
# Out:
#           date         home_team   away_team  home_score  away_score  \
# 0   1979-07-20        Kyrgyzstan   Lithuania           0           0
# 7   1990-05-27           Georgia   Lithuania           2           2
# 9   1991-11-17         Lithuania      Latvia           1           1
# 11  1992-04-28  Northern Ireland   Lithuania           2           2
# 12  1992-05-20           Moldova   Lithuania           1           1
# ..         ...               ...         ...         ...         ...
# 334 2018-06-05         Lithuania      Latvia           1           1
# 353 2019-03-25        Azerbaijan   Lithuania           0           0
# 354 2019-03-25        Azerbaijan   Lithuania           0           0
# 355 2019-06-07         Lithuania  Luxembourg           1           1
# 356 2019-06-07         Lithuania  Luxembourg           1           1
#
#                        tourniment      city           country  ivarciu_suma  \
# ...

# %%
# Kokiai šaliai pralošėme didžiausiu  ivarčių skirtumu, žasidami namuose, kada tai įvyko, kokiame mieste vyko rungtynės?
# df.loc[ df['city'].isin( ['Vilnius', 'Kaunas' ] ), ['date', 'home_score', 'away_score'] ]

#df.loc[ (df['country'].isin( ['Lithuania' ] )) & (df.max('ivarciu_skirtumas')) ]
#df

#df[ (df['home_team'] == 'Lithuania') & (df['ivarciu_skirtumas'] < 0)].sort_values('ivarciu_skirtumas',ascending=True).iloc[0]
df[ df['home_team'] == 'Lithuania'].sort_values('ivarciu_skirtumas',ascending=True).iloc[0]
# Out:
# date                          2000-10-11 00:00:00
# home_team                               Lithuania
# away_team                                 Hungary
# home_score                                      1
# away_score                                      6
# tourniment           FIFA World Cup qualification
# city                                       Kaunas
# country                                 Lithuania
# ivarciu_suma                                    7
# ivarciu_skirtumas                              -5
# Name: 108, dtype: object

# %%
# Kiek rungtynių Lietuva pralaimėjo žaisdama svetur?
len(df[ (df['away_team'] == 'Lithuania') & (df['ivarciu_skirtumas'] > 0)])
# Out:
# 138

# %%
# Kiek rungtynių Lietuva laimėjo žaisdama svetur?
len(df[ (df['away_team'] == 'Lithuania') & (df['ivarciu_skirtumas'] < 0 ) ] )
# Out:
# 39

# %%
#Kiek rungtynių Lietuva laimėjo žaisdama Lietuvoje?
len(df[ (df['home_team'] == 'Lithuania') & (df['ivarciu_skirtumas'] > 0)])
# Out:
# 49

# %%
# Kiek rungtynių Lietuva praleimėjo žaisdama Lietuvoje?
len(df[ (df['home_team'] == 'Lithuania') & (df['ivarciu_skirtumas'] < 0 ) & (df['country'] == 'Lithuania') ])
# Out:
# 60

# %%
# Kiek rungtynių Lietuviai sužaidė lygiosiomis namuose?
len( df[ (df['home_team'] == 'Lithuania') & (df['ivarciu_skirtumas'] == 0 ) ] )
# Out:
# 31

# %%
# Kiek rungtynių Lietuviai sužaidė lygiosiomis išvykoje?
len( df[ (df['away_team'] == 'Lithuania') & (df['ivarciu_skirtumas'] == 0 ) ] )
# Out:
# 42

# %% [markdown]
# # Groupby

# %%
df
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 3   1979-07-28   Lithuania    Ukraine           0           2
# 4   1979-07-30      Russia  Lithuania           2           0
# ..         ...         ...        ...         ...         ...
# 362 2019-09-10   Lithuania   Portugal           1           5
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
# 365 2019-10-14   Lithuania     Serbia           1           2
# 366 2019-10-14   Lithuania     Serbia           1           2
#
#                   tourniment     city       country  ivarciu_suma  \
# 0                   Friendly   Moscow  Soviet Union             0
# 1                   Friendly   Moscow  Soviet Union             5
# ...

# %%
df.groupby('home_team').sum()#susumuos skaitines vertes
# Out:
# C:\Users\Donciukas\AppData\Local\Temp\ipykernel_19520\428363738.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('home_team').sum()#susumuos skaitines vertes
#                         home_score  away_score  ivarciu_suma  \
# home_team
# Albania                         10           4            14
# Andorra                          1           3             4
# Argentina                        0           0             0
# Armenia                          8           6            14
# Austria                          6           1             7
# Azerbaijan                       2           2             4
# Belarus                         10           6            16
# Belgium                          1           1             2
# ...

# %%
df.groupby('home_team').sum().loc['Lithuania', ['home_score', 'away_score']]# galima konretizuot
# Out:
# C:\Users\Donciukas\AppData\Local\Temp\ipykernel_19520\4163070068.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('home_team').sum().loc['Lithuania', ['home_score', 'away_score']]# galima konretizuot
# home_score    156
# away_score    193
# Name: Lithuania, dtype: int64

# %%
import numpy as np

# %%
def my_function(groupvalue):

    return len(groupvalue)

df.groupby('home_team').agg(# galima surodyti daugiau nei viena funkcija
    [np.sum, np.mean, my_function]
)
# Out:
# C:\Users\Donciukas\AppData\Local\Temp\ipykernel_19520\692818748.py:5: FutureWarning: ['date', 'away_team', 'tourniment', 'city', 'country'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('home_team').agg(# galima surodyti daugiau nei viena funkcija
#                        home_score                       away_score            \
#                               sum      mean my_function        sum      mean
# home_team
# Albania                        10  2.500000           4          4  1.000000
# Andorra                         1  1.000000           1          3  3.000000
# Argentina                       0  0.000000           1          0  0.000000
# Armenia                         8  2.000000           4          6  1.500000
# Austria                         6  3.000000           2          1  0.500000
# ...

# %%
df
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 3   1979-07-28   Lithuania    Ukraine           0           2
# 4   1979-07-30      Russia  Lithuania           2           0
# ..         ...         ...        ...         ...         ...
# 362 2019-09-10   Lithuania   Portugal           1           5
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
# 365 2019-10-14   Lithuania     Serbia           1           2
# 366 2019-10-14   Lithuania     Serbia           1           2
#
#                   tourniment     city       country  ivarciu_suma  \
# 0                   Friendly   Moscow  Soviet Union             0
# 1                   Friendly   Moscow  Soviet Union             5
# ...

# %%
df.rename( columns = {'tourniment': 'tournament' })
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 3   1979-07-28   Lithuania    Ukraine           0           2
# 4   1979-07-30      Russia  Lithuania           2           0
# ..         ...         ...        ...         ...         ...
# 362 2019-09-10   Lithuania   Portugal           1           5
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
# 365 2019-10-14   Lithuania     Serbia           1           2
# 366 2019-10-14   Lithuania     Serbia           1           2
#
#                   tournament     city       country  ivarciu_suma  \
# 0                   Friendly   Moscow  Soviet Union             0
# 1                   Friendly   Moscow  Soviet Union             5
# ...

# %%
# # Kiek ivarciu lietuviai imuse ir praleido zaisdami skirtinguose cempionatuose, zaisdami isvykoje?
# 1. Atsifiltruoti, ten kur lietuviai zaide isvykoje
# 2. Sugrupuoti pagal tournamenta
# 3. Pasirinkti stulpelius home_score ir away_score
# 4. Gale prideti .sum()
#len( df[ (df['home_team'] == 'Lithuania') & (df['ivarciu_skirtumas'] == 0 ) ] )

# %%
#df[ (df['away_team'] == 'Lithuania').loc[ [ 'city', 'country']]]
#df[ (df['away_team'] == 'Lithuania')]

#df.groupby((df['tournament'] == 'Lithuania')).agg(# galima surodyti daugiau nei viena funkcija
#    [np.sum, np.mean, my_function]
#)
# df.groupby('home_team').sum().loc['Lithuania', ['home_score', 'away_score']]#
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 4   1979-07-30      Russia  Lithuania           2           0
# 5   1979-08-01     Belarus  Lithuania           0           2
# ..         ...         ...        ...         ...         ...
# 354 2019-03-25  Azerbaijan  Lithuania           0           0
# 357 2019-06-10      Serbia  Lithuania           4           1
# 358 2019-06-10      Serbia  Lithuania           4           1
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
#
#                   tourniment      city       country  ivarciu_suma  \
# 0                   Friendly    Moscow  Soviet Union             0
# 1                   Friendly    Moscow  Soviet Union             5
# ...

# %%
df[ df['away_team'] == 'Lithuania'].groupby('tourniment').sum()[ ['home_score', 'away_score']]
# df[ df['away_team'] == 'Lithuania' ].groupby('tournament').sum()[ ['home_score', 'away_score'] ]
# Out:
# C:\Users\Donciukas\AppData\Local\Temp\ipykernel_19520\235218478.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[ df['away_team'] == 'Lithuania'].groupby('tourniment').sum()[ ['home_score', 'away_score']]
#                                  home_score  away_score
# tourniment
# Baltic Cup                               43          35
# Cyprus International Tournament           8           6
# FIFA World Cup qualification             80          29
# Friendly                                189          67
# Malta International Tournament            1           1
# UEFA Euro qualification                  73          29
# UEFA Nations League                      18           2

# %% [markdown]
# # Merge, join, concatenate

# %% [markdown]
# # Matplotlib

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#      - -------------------------------------- 0.3/7.6 MB 8.6 MB/s eta 0:00:01
#      --- ------------------------------------ 0.6/7.6 MB 7.1 MB/s eta 0:00:01
#      ----- ---------------------------------- 1.1/7.6 MB 8.9 MB/s eta 0:00:01
#      -------- ------------------------------- 1.6/7.6 MB 9.3 MB/s eta 0:00:01
#      ---------- ----------------------------- 2.1/7.6 MB 10.0 MB/s eta 0:00:01
#      ------------- -------------------------- 2.5/7.6 MB 10.0 MB/s eta 0:00:01
#      --------------- ------------------------ 3.0/7.6 MB 10.5 MB/s eta 0:00:01
#      ----------------- ---------------------- 3.4/7.6 MB 10.4 MB/s eta 0:00:01
#      -------------------- ------------------- 3.9/7.6 MB 10.8 MB/s eta 0:00:01
#      ---------------------- ----------------- 4.3/7.6 MB 10.6 MB/s eta 0:00:01
#      ------------------------ --------------- 4.8/7.6 MB 10.8 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import numpy as np
x =np.arange(0,100)
y = x*5
z = x ** 2

# %%
fig = plt.figure()
ax = fig.add_axes( (0,0,1,1) )

ax.plot( x, y ) 
ax.set_xlabel('X asis')
ax.set_ylabel('Y asis')
ax.set_title('Pavadinimas')
# Out:
# Text(0.5, 1.0, 'Pavadinimas')

# %%
fig = plt.figure()
ax = fig.add_axes( (0,0,1,1) )
print(z[50])
z[49] = 25000
z[50] = 22000
ax.plot( x, z )
ax_2 = fig.add_axes( (0.3,0.5,0.2,0.2) )# x start, y start, width, height
ax_2.set_xlim(48,52)
ax_2.set_ylim(2100,2600)
# Out:
# 22000
# (2100.0, 2600.0)
